# %%
import featuretools as ft

data = ft.demo.load_mock_customer()
transactions_df = data["transactions"].merge(data["sessions"]).merge(data["customers"])

transactions_df.sample(10)
# Out:
#      transaction_id  session_id    transaction_time product_id  amount  \
# 264             296          20 2014-01-01 04:46:00          5   53.22
# 19               74           2 2014-01-01 00:20:35          1  106.99
# 314             141          23 2014-01-01 05:40:10          5  128.26
# 290             236          21 2014-01-01 05:14:10          5   57.09
# 379             292          28 2014-01-01 06:50:35          1  133.71
# 335             482          25 2014-01-01 06:02:55          1   26.30
# 293             452          21 2014-01-01 05:17:25          5   69.62
# 271             169          20 2014-01-01 04:53:35          3   78.87
# 404             476          29 2014-01-01 07:17:40          4   11.62
# 179              72          12 2014-01-01 03:13:55          2  143.96
#
#      customer_id   device       session_start zip_code           join_date  \
# 264            5  desktop 2014-01-01 04:46:00    60091 2010-07-17 05:27:50
# 19             5   mobile 2014-01-01 00:17:20    60091 2010-07-17 05:27:50
# 314            3  desktop 2014-01-01 05:32:35    13244 2011-08-13 15:42:34
# 290            4  desktop 2014-01-01 05:02:15    60091 2011-04-08 20:08:14
# 379            5   mobile 2014-01-01 06:50:35    60091 2010-07-17 05:27:50
# 335            3  desktop 2014-01-01 05:59:40    13244 2011-08-13 15:42:34
# 293            4  desktop 2014-01-01 05:02:15    60091 2011-04-08 20:08:14
# 271            5  desktop 2014-01-01 04:46:00    60091 2010-07-17 05:27:50
# 404            1   mobile 2014-01-01 07:10:05    60091 2011-04-17 10:48:33
# 179            4  desktop 2014-01-01 03:04:10    60091 2011-04-08 20:08:14
#
#       birthday
# 264 1984-07-28
# 19  1984-07-28
# 314 2003-11-21
# 290 2006-08-15
# 379 1984-07-28
# 335 2003-11-21
# 293 2006-08-15
# 271 1984-07-28
# 404 1994-07-18
# 179 2006-08-15

# %%
products_df = data["products"]
products_df
# Out:
#   product_id brand
# 0          1     B
# 1          2     B
# 2          3     B
# 3          4     B
# 4          5     A

# %%
es = ft.EntitySet(id="customer_data")

from woodwork.logical_types import Categorical, PostalCode

es = es.add_dataframe(
    dataframe_name="transactions",
    dataframe=transactions_df,
    index="transaction_id",
    time_index="transaction_time",
    logical_types={
        "product_id": Categorical,
        "zip_code": PostalCode,
    },
)

es
# Out:
# /mnt/c/Users/james/projects/auto-feature-engineering/.venv/lib/python3.10/site-packages/woodwork/type_sys/utils.py:33: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(
# /mnt/c/Users/james/projects/auto-feature-engineering/.venv/lib/python3.10/site-packages/woodwork/type_sys/utils.py:33: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(
# Entityset: customer_data
#   DataFrames:
#     transactions [Rows: 500, Columns: 11]
#   Relationships:
#     No relationships

# %%
es["transactions"].ww.schema
# Out:
#                  Logical Type Semantic Tag(s)
# Column
# transaction_id        Integer       ['index']
# session_id            Integer     ['numeric']
# transaction_time     Datetime  ['time_index']
# product_id        Categorical    ['category']
# amount                 Double     ['numeric']
# customer_id           Integer     ['numeric']
# device            Categorical    ['category']
# session_start        Datetime              []
# zip_code           PostalCode    ['category']
# join_date            Datetime              []
# birthday             Datetime              []

# %%
es = es.add_dataframe(
    dataframe_name="products", dataframe=products_df, index="product_id"
)

es
# Out:
# /mnt/c/Users/james/projects/auto-feature-engineering/.venv/lib/python3.10/site-packages/woodwork/type_sys/utils.py:33: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(
# /mnt/c/Users/james/projects/auto-feature-engineering/.venv/lib/python3.10/site-packages/woodwork/type_sys/utils.py:33: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(
# Entityset: customer_data
#   DataFrames:
#     transactions [Rows: 500, Columns: 11]
#     products [Rows: 5, Columns: 2]
#   Relationships:
#     No relationships

# %%
es = es.add_relationship("products", "product_id", "transactions", "product_id")
es
# Out:
# Entityset: customer_data
#   DataFrames:
#     transactions [Rows: 500, Columns: 11]
#     products [Rows: 5, Columns: 2]
#   Relationships:
#     transactions.product_id -> products.product_id

# %%
es = es.normalize_dataframe(
    base_dataframe_name="transactions",
    new_dataframe_name="sessions",
    index="session_id",
    make_time_index="session_start",
    additional_columns=[
        "device",
        "customer_id",
        "zip_code",
        "session_start",
        "join_date",
    ],
)
es
# Out:
# Entityset: customer_data
#   DataFrames:
#     transactions [Rows: 500, Columns: 6]
#     products [Rows: 5, Columns: 2]
#     sessions [Rows: 35, Columns: 6]
#   Relationships:
#     transactions.product_id -> products.product_id
#     transactions.session_id -> sessions.session_id

# %%
es["transactions"].ww.schema
# Out:
#                  Logical Type              Semantic Tag(s)
# Column
# transaction_id        Integer                    ['index']
# session_id            Integer   ['foreign_key', 'numeric']
# transaction_time     Datetime               ['time_index']
# product_id        Categorical  ['category', 'foreign_key']
# amount                 Double                  ['numeric']
# birthday             Datetime                           []

# %%
es = es.normalize_dataframe(
    base_dataframe_name="sessions",
    new_dataframe_name="customers",
    index="customer_id",
    make_time_index="join_date",
    additional_columns=["zip_code", "join_date"],
)

es
# Out:
# Entityset: customer_data
#   DataFrames:
#     transactions [Rows: 500, Columns: 6]
#     products [Rows: 5, Columns: 2]
#     sessions [Rows: 35, Columns: 4]
#     customers [Rows: 5, Columns: 3]
#   Relationships:
#     transactions.product_id -> products.product_id
#     transactions.session_id -> sessions.session_id
#     sessions.customer_id -> customers.customer_id

# %%
feature_matrix, feature_defs = ft.dfs(entityset=es, target_dataframe_name="products")

feature_matrix
# Out:
# /mnt/c/Users/james/projects/auto-feature-engineering/.venv/lib/python3.10/site-packages/featuretools/computational_backends/feature_set_calculator.py:785: FutureWarning: The provided callable <function mean at 0x7fad7c63d240> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ).agg(to_agg)
# /mnt/c/Users/james/projects/auto-feature-engineering/.venv/lib/python3.10/site-packages/featuretools/computational_backends/feature_set_calculator.py:785: FutureWarning: The provided callable <function std at 0x7fad7c63d360> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   ).agg(to_agg)
# /mnt/c/Users/james/projects/auto-feature-engineering/.venv/lib/python3.10/site-packages/featuretools/computational_backends/feature_set_calculator.py:785: FutureWarning: The provided callable <function min at 0x7fad7c63ca60> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   ).agg(to_agg)
# /mnt/c/Users/james/projects/auto-feature-engineering/.venv/lib/python3.10/site-packages/featuretools/computational_backends/feature_set_calculator.py:785: FutureWarning: The provided callable <function sum at 0x7fad7c63c310> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   ).agg(to_agg)
# /mnt/c/Users/james/projects/auto-feature-engineering/.venv/lib/python3.10/site-packages/featuretools/computational_backends/feature_set_calculator.py:785: FutureWarning: The provided callable <function max at 0x7fad7c63c940> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ).agg(to_agg)
#             COUNT(transactions)  MAX(transactions.amount)  \
# product_id
# 1                           102                    149.56
# 2                            92                    149.95
# 3                            96                    148.31
# 4                           106                    146.46
# 5                           104                    149.02
#
#             MEAN(transactions.amount)  MIN(transactions.amount)  \
# product_id
# 1                           73.429314                      6.84
# 2                           76.319891                      5.73
# 3                           73.001250                      5.89
# 4                           76.311038                      5.81
# 5                           76.264904                      5.91
#
#             SKEW(transactions.amount)  STD(transactions.amount)  \
# product_id
# 1                            0.125525                 42.479989
# 2                            0.151934                 46.336308
# 3                            0.223938                 38.871405
# 4                           -0.132077                 42.492501
# 5                            0.098248                 42.131902
#
#             SUM(transactions.amount) MODE(transactions.DAY(birthday))  \
# product_id
# 1                            7489.79                               18
# 2                            7021.43                               18
# 3                            7008.12                               18
# 4                            8088.97                               18
# 5                            7931.55                               18
#
#            MODE(transactions.DAY(transaction_time))  \
# product_id
# 1                                                 1
# 2                                                 1
# 3                                                 1
# 4                                                 1
# 5                                                 1
#
#            MODE(transactions.MONTH(birthday))  ...  \
# product_id                                     ...
# 1                                           7  ...
# 2                                           8  ...
# 3                                           8  ...
# 4                                           7  ...
# 5                                           7  ...
#
#            MODE(transactions.sessions.device)  \
# product_id
# 1                                     desktop
# 2                                     desktop
# 3                                     desktop
# 4                                     desktop
# 5                                      mobile
#
#            NUM_UNIQUE(transactions.DAY(birthday))  \
# product_id
# 1                                               4
# 2                                               4
# 3                                               4
# 4                                               4
# 5                                               4
#
#            NUM_UNIQUE(transactions.DAY(transaction_time))  \
# product_id
# 1                                                       1
# 2                                                       1
# 3                                                       1
# 4                                                       1
# 5                                                       1
#
#            NUM_UNIQUE(transactions.MONTH(birthday))  \
# product_id
# 1                                                 3
# 2                                                 3
# 3                                                 3
# 4                                                 3
# 5                                                 3
#
#            NUM_UNIQUE(transactions.MONTH(transaction_time))  \
# product_id
# 1                                                         1
# 2                                                         1
# 3                                                         1
# 4                                                         1
# 5                                                         1
#
#            NUM_UNIQUE(transactions.WEEKDAY(birthday))  \
# product_id
# 1                                                   4
# 2                                                   4
# 3                                                   4
# 4                                                   4
# 5                                                   4
#
#             NUM_UNIQUE(transactions.WEEKDAY(transaction_time))  \
# product_id
# 1                                                           1
# 2                                                           1
# 3                                                           1
# 4                                                           1
# 5                                                           1
#
#             NUM_UNIQUE(transactions.YEAR(birthday))  \
# product_id
# 1                                                 5
# 2                                                 5
# 3                                                 5
# 4                                                 5
# 5                                                 5
#
#             NUM_UNIQUE(transactions.YEAR(transaction_time))  \
# product_id
# 1                                                         1
# 2                                                         1
# 3                                                         1
# 4                                                         1
# 5                                                         1
#
#             NUM_UNIQUE(transactions.sessions.device)
# product_id
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
# 5                                                  3
#
# [5 rows x 25 columns]
